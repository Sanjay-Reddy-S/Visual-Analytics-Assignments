# %% [markdown]
# # Interactive WordCloud
#
# By:
#  - Aditya Agrawal (adityaagrawa@cs.umass.edu)
#  - Sanjay Reddy S (ssatti@umass.edu)

# %% [markdown]
# #### Works on Python 3
#
#     - Please ensure 'nysk.xml' is in the same directory.
#
# This file presents the code and the plot for visualizing top 'n' most frequent occurences from our text (Source: http://archive.ics.uci.edu/ml/datasets/NYSK#) where the parameter 'n' can be interactively selected and viewed, limited to a maximum of 500 for demonstration purposes. We can scale the size, dimensions according to our main dataset from the VAST Challenge. This visualization can be used to look at the most talked about, or the most frequent occurence in our articles, as well as emails dataset from VAST Challenge 2014.

# %% [markdown]
# ### Importing Libraries & Housekeeping Jobs

# %%
# %load_ext autoreload
# %autoreload 2

#Importing Libraries
import xml.etree.ElementTree as ET
import pandas as pd
from wordcloud import WordCloud
import pickle

#NLTK
import nltk
from nltk import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

#Bokeh
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource
from bokeh.layouts import column, row, widgetbox
from bokeh.models import HoverTool, Plot
from bokeh.palettes import Spectral6
from bokeh.io import *
from bokeh.models.glyphs import ImageURL
from bokeh.models.widgets import Slider
from bokeh.application import Application
from bokeh.application.handlers import FunctionHandler
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4fd76507-eac7-40d7-bed9-60f121c6dab4">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Handling XML Data as a Pandas Frame
#
# Our data is present an an xml file, thus we had to pre-process it to obtain our normal flat-table data for exploration and further processing.

# %%
xml_data = open('nysk.xml').read()

def xml2df(xml_data):
    root = ET.XML(xml_data) # element tree
    all_records = []
    for i, child in enumerate(root):
        record = {}
        for subchild in child:
            record[subchild.tag] = subchild.text
            all_records.append(record)
    return pd.DataFrame(all_records)
data = xml2df(xml_data).drop_duplicates()

# %% [markdown]
# ### BOW and Word Frequency Exploration
#  - Word Cloud- For Visualizing top 'n' words
#  - Histogram- For Looking at top 'n' words (present as a separate file.)
#
# Here we explore the 'Bag of Words' representation of our dataset, and use the same for creating Interactive Wordcloud and an interactive histogram.

# %%
all_news = ' '.join(data.text.values)
all_news_lower = all_news.lower()

tokenizer = RegexpTokenizer(r'\w+')

news_frequency_distribution = FreqDist(tokenizer.tokenize(all_news_lower))
news_frequency_distribution.most_common(10)

stopWords = set(stopwords.words('english'))

#Removing punctuation and stopwords
for stopword in stopWords:
    if stopword in news_frequency_distribution:
        del news_frequency_distribution[stopword]

# %% [markdown]
# # Setting up the WordCloud
#
# The below code could take awhile to render, as the wordcloud is created on-the-fly, saved locally and then rendered back. After intialization, it gets alot faster.
#
# (Could throw an error on the first attempt to run the code or so, please try running atleast a few times. Though it runs perfectly after restarting almost everytime on our systems.)

# %%
wordcloud = WordCloud(
    width=1000,
    height=1000,
    max_words=500,
    scale=3,
)

wordcloud.generate_from_frequencies(dict(news_frequency_distribution.most_common(200)))
wordcloud.to_file("news-wordcloud_1.png")

count = 1
    
def modify_doc1(doc):
    #Plotting in Bokeh
    def create_figure():
        global count
        p = figure(x_range=(0,1), y_range=(0,1))
        p.image_url(url = ["news-wordcloud_{}.png".format(count)], x=0, y=1, w=1, h=1)
        p.axis.visible = False
        return p
        #show(p)
    
    #Setting Up Widgets
    num_most_freq = Slider(title="Number of Most frequent words", value=50 , start=50, end=500 , step=50)
    inputs = widgetbox(num_most_freq)
    
    # Set up callbacks
    def update_data(attrname, old, new):
        global count
        # Get the current slider values
        n = num_most_freq.value
        count += 1
        # Generate New Word Cloud
        wordcloud.generate_from_frequencies(dict(news_frequency_distribution.most_common(n)))
        wordcloud.to_file("news-wordcloud_{}.png".format(count))
        #p.image_url( url=[ "news-wordcloud.png"],
        #    x=1, y=1, w=1000, h=1000, anchor="bottom_left")
        layout.children[1] = create_figure()
        
    num_most_freq.on_change('value', update_data)
    layout = row(inputs, create_figure(), width=800)
    doc.add_root(layout)

handler1 = FunctionHandler(modify_doc1)
app1 = Application(handler1)
app1.create_document()
show(app1, notebook_url= 'localhost:8888')
# Out:
# <script type='text/javascript'>
#
# var target = document.getElementById('notebook-container');
#
# var observer = new MutationObserver(function(mutations) {
#
#    for (var i = 0; i < mutations.length; i++) {
#       for (var j=0; j < mutations[i].removedNodes.length; j++) {
#         for (var k=0; k < mutations[i].removedNodes[j].childNodes.length; k++)
#           var bokeh_selector = $(mutations[i].removedNodes[j].childNodes[k]).find(".bokeh_class");
#           if (bokeh_selector) {
#             if (bokeh_selector.length > 0) {
#                var destroyed_id = bokeh_selector[0].id;
#
# var cmd = "from bokeh import io; io._destroy_server('<%= destroyed_id %>')";
# var command = _.template(cmd)({destroyed_id:destroyed_id});
# Jupyter.notebook.kernel.execute(command);
#
#             }
#           }
#       }
#    }
# });
# observer.observe(target, { childList: true, subtree:true });</script>
# <div class='bokeh_class' id='b46f128b0113438c96391c099307047a'>
# <script
#     src="http://localhost:57305/autoload.js?bokeh-autoload-element=02901803-a941-45ad-bebf-25e785e46f92&bokeh-app-path=/&bokeh-absolute-url=http://localhost:57305"
#     id="02901803-a941-45ad-bebf-25e785e46f92"
#     data-bokeh-model-id=""
#     data-bokeh-doc-id=""
# ></script></div>

# %%
# NER Tagging
from nltk import pos_tag, ne_chunk, word_tokenize
from collections import defaultdict
"""
myTree = ne_chunk(pos_tag(word_tokenize(all_news)))
NER_tags = []
for chunk in myTree:
    if hasattr(chunk, 'label'):
        NER_tags.append((chunk.label(), ' '.join(c[0] for c in chunk)))

#   TAKES A REALLLLY LONG TIME TO RUN!

NER_dict = defaultdict()         
for label, entity in NER_tags:
    if label not in NER_dict:
        NER_dict[label] = defaultdict(float)
    NER_dict[label][entity] += 1

#   SAVE THE NER_DICT OBJECT LOCALLY!

import pickle
def save_object(obj, filename):
    with open(filename, 'wb') as output:
        pickle.dump(obj, output, pickle.HIGHEST_PROTOCOL)
save_object(NER_dict, 'NER_dict.pkl')

"""
#   For Loading the NER_dict object:
    
with open(r"NER_dict.pkl", "rb") as input_file:
    NER_dict = pickle.load(input_file)

NER_dict
# Out:
# defaultdict(None,
#             {'FACILITY': defaultdict(float,
#                          {'60th Street': 1.0,
#                           '845-548-5383 Check': 1.0,
#                           'Air': 5.0,
#                           'Air Chance': 2.0,
#                           'Air Force': 2.0,
#                           'Air Force One': 1.0,
#                           'Air France': 594.0,
#                           'Air France Flight': 1.0,
#                           'Air France Jet': 1.0,
#                           'Air France Passenger Names Probed': 1.0,
#                           'Air France-KLM': 2.0,
#                           'Air Malta': 3.0,
#                           'Air Talent': 1.0,
#                           'Air Talent P1Research Dubai': 1.0,
#                           'Air Transport': 1.0,
#                           'Al Jazeera': 1.0,
#                           'Al Jazira Financial Services': 1.0,
#                           'Al Manai': 3.0,
#                           'Al Sadd Stadium': 1.0,
#                           'Anuradhapura Bikkhu University Ven Homagama Dhammanada': 1.0,
#                           'Aphrodite': 1.0,
#                           'Apple Supplier Foxconn': 4.0,
#                           'Art Hop': 1.0,
#                           'Ashmore Investment Management': 2.0,
#                           'Athens Alpha Bank': 1.0,
#                           'Baba Ramdev Yog Patanjali': 2.0,
#                           'Bank Street': 1.0,
#                           'Barack Street': 2.0,
#                           'Beijing Antaike': 1.0,
#                           'Berlin': 2.0,
#                           'Best City': 2.0,
#                           'Best Western Cairn Croft': 4.0,
#                           'Bite Into': 2.0,
#                           'Bite Out': 4.0,
#                           'Bligh Street': 1.0,
#                           'Blythe Hall': 1.0,
#                           'Boat House Row': 1.0,
#                           'Bretton Woods': 16.0,
#                           'Bretton Woods Committee': 2.0,
#                           'Bristol Hotel': 6.0,
#                           'Bristol Palace': 4.0,
#                           'Bristol Plaza': 173.0,
#                           'Bristol Plaza Dominique': 1.0,
#                           'Broadcasting Board': 1.0,
#                           'Broadcasting House Call': 1.0,
#                           'Buckingham Palace': 14.0,
#                           'Bulgarian Development Bank': 2.0,
#                           'California State Prison': 7.0,
#                           'Camden Sound': 1.0,
#                           'Camp Lejeune': 1.0,
#                           'Camping': 2.0,
#                           'Cannes': 5.0,
#                           'Cannes Is Great': 1.0,
#                           'Cantor Fitzgerald': 2.0,
#                           'Cape Canaveral': 1.0,
#                           'Capitol Hill': 4.0,
#                           'Casey Anthony': 1.0,
#                           'Centre Street': 4.0,
#                           'Chatham House': 12.0,
#                           'Chinese G20': 1.0,
#                           'Chuo Mitsui Trust': 12.0,
#                           'Church House': 1.0,
#                           'Circuit House': 1.0,
#                           'City': 5.0,
#                           'City Airport': 2.0,
#                           'City College': 1.0,
#                           'City Gate': 1.0,
#                           'City Hall East': 1.0,
#                           'City Index': 1.0,
#                           'Cleveland Park': 1.0,
#                           'Coast Guard Academy': 2.0,
#                           'Cockshutt Park': 1.0,
#                           'College Park High': 1.0,
#                           'Cove Island': 3.0,
#                           'Crimean War': 2.0,
#                           'Critics': 1.0,
#                           'Croke Park': 2.0,
#                           'Cross Island Pkwy': 1.0,
#                           'Crown Office Row': 1.0,
#                           'Crown Prosecution': 1.0,
#                           'Da Silvano': 2.0,
#                           'Dana Farber Cancer Institute': 1.0,
#                           'Dark Road': 2.0,
#                           'De Maizière': 1.0,
#                           'Dolomite Mountains': 2.0,
#                           'Downing Street': 7.0,
#                           'Dubai World': 1.0,
#                           'Dublin': 8.0,
#                           'Dublin Castle': 12.0,
#                           'Dublin Castle Top Leadership Stories': 1.0,
#                           'Dublin North': 1.0,
#                           'Dumbarton Street': 1.0,
#                           'Ed': 1.0,
#                           'El Bulli': 1.0,
#                           'El Paso': 1.0,
#                           'El Tiempo': 1.0,
#                           'Elite': 2.0,
#                           'Elite Psychiatric Therapy Dog Program': 13.0,
#                           'Emir Cup': 1.0,
#                           'Estonia': 1.0,
#                           'Euro RSCG Worldwide': 1.0,
#                           'Ewood': 1.0,
#                           'Executive Office': 1.0,
#                           'Favorite Dancer': 1.0,
#                           'Favorite Sex Scandal': 1.0,
#                           'Favorite Subject': 1.0,
#                           'Fayerweather Hall': 2.0,
#                           'Feile Restaurant': 1.0,
#                           'Fern Drive': 3.0,
#                           'Fifth Amendment': 1.0,
#                           'Fifth Avenue': 2.0,
#                           'Fifth Circuit': 1.0,
#                           'Fifth Great': 6.0,
#                           'Fifth Republic': 2.0,
#                           'Film Independent Spirit Awards': 1.0,
#                           'First Avenue': 1.0,
#                           'Five Biggest': 4.0,
#                           'Fleet Street': 1.0,
#                           'Fleet Street Letter': 5.0,
#                           'France Inter': 1.0,
#                           'Franklin St': 1.0,
#                           'Franklin St.': 3.0,
#                           'Franklin Street': 17.0,
#                           'Friendship House': 1.0,
#                           'G8': 1.0,
#                           'G8 Deauville': 2.0,
#                           'Garda': 1.0,
#                           'Garden': 1.0,
#                           'Grand': 1.0,
#                           'Grand Canyon': 2.0,
#                           'Grand Disaster': 1.0,
#                           'Grand Hyatt': 6.0,
#                           'Grand Inquisitors': 1.0,
#                           'Grand Jury': 6.0,
#                           'Grand Mosque': 1.0,
#                           'Grand Old': 2.0,
#                           'Grand Orient Lodge': 2.0,
#                           'Grand Palais': 1.0,
#                           'Grand Parade': 1.0,
#                           'Grand Prix': 3.0,
#                           'Grand Prize': 1.0,
#                           'Grand Rapids': 1.0,
#                           'Grand Rapids Street Car': 6.0,
#                           'Granite Staters': 1.0,
#                           'Gray Chrysler Dodge Jeep Ram': 1.0,
#                           'Great Hall': 1.0,
#                           'Greenwich Street': 1.0,
#                           'Harmony Square': 1.0,
#                           'Heart Xccelerate Xposé': 2.0,
#                           'Home': 24.0,
#                           'Hotel Du Cap': 14.0,
#                           'Hotel Sofitel': 1.0,
#                           'Imara SP Reid': 2.0,
#                           'Infomercials': 1.0,
#                           'Iqbal Stadium Faisalabad': 7.0,
#                           'J P Morgan': 1.0,
#                           'Jacksonville Farmer': 1.0,
#                           'Jay Street': 1.0,
#                           'Joplin Regional Medical Center': 2.0,
#                           'Joplin Tornado': 2.0,
#                           'Kennedy': 4.0,
#                           'Kennedy Airport': 55.0,
#                           'Kennedy Center': 1.0,
#                           'Kennedy Space Center': 15.0,
#                           'Kennedy Space Center First Bay Area Hippie': 1.0,
#                           'Kensington Palace': 2.0,
#                           'Khalifa Stadium': 1.0,
#                           'Kremlin': 9.0,
#                           'Kremlin Auschwitz': 1.0,
#                           'Kremlin Got Tip': 4.0,
#                           'Kremlin Revolutions': 4.0,
#                           'Kremlin Will Medvedev': 3.0,
#                           'La Guardia Airport': 1.0,
#                           'La Rotonde': 1.0,
#                           'Large Brent Baker Senior Editors Tim Graham Rich Noyes': 2.0,
#                           'Large Weekends': 7.0,
#                           'Leadenhall Street': 1.0,
#                           'Litchfield Street': 3.0,
#                           'Lombard Street Research': 1.0,
#                           'Lucknow Street': 1.0,
#                           'Madhura Murali': 1.0,
#                           'Madison Avenue': 1.0,
#                           'Madison Wisconsin': 6.0,
#                           'Mail AT': 2.0,
#                           'Main Street': 16.0,
#                           'Manhattan': 16.0,
#                           'Manhattan Criminal': 31.0,
#                           'Manhattan Criminal Court': 305.0,
#                           'Manhattan Criminal Courtin New York': 1.0,
#                           'Manhattan Criminal Courts': 2.0,
#                           'Manhattan Hotel': 1.0,
#                           'Manhattan Madam': 4.0,
#                           'Manhattan Sofitel': 14.0,
#                           'Manhattan Special Victims Squad': 2.0,
#                           'Manhattan Special Victims Unit': 4.0,
#                           'Mansion House': 1.0,
#                           'Manufactured Products': 4.0,
#                           'Marlin': 1.0,
#                           'Maronite Catholic Saint Maron': 3.0,
#                           'Mayflower Hotel': 1.0,
#                           'Millenium': 2.0,
#                           'Millenium Stadium': 1.0,
#                           'Millennium Dome': 1.0,
#                           'Mohatta Palace How': 1.0,
#                           'Monmouth Street': 1.0,
#                           'Murwillumbah': 1.0,
#                           'N CLINTON': 1.0,
#                           'N Fletcher': 7.0,
#                           'Nagapattinam District': 1.0,
#                           'Neuroscience Behind Sexual': 1.0,
#                           'Nite': 6.0,
#                           'North Street': 3.0,
#                           'Northeastern University': 2.0,
#                           'Northwestern University': 2.0,
#                           'Notre Dame Cathedral': 1.0,
#                           'One Hanson': 2.0,
#                           'Oregon Twilight': 1.0,
#                           'Orlando Airport': 2.0,
#                           'Oval': 2.0,
#                           'Oval Office': 38.0,
#                           'Pace Law School': 7.0,
#                           'Palace': 3.0,
#                           'Palace Elysee': 1.0,
#                           'Palace Theatre': 4.0,
#                           'Palau Sant Jordi': 1.0,
#                           'Palestinians Jeffrey St. Clair How Green': 6.0,
#                           'Palestinians Noam Chomsky': 1.0,
#                           'Palin Meter': 2.0,
#                           'Palm Center': 1.0,
#                           'Palmer Street': 1.0,
#                           'Papago Park': 1.0,
#                           'Park': 3.0,
#                           'Park Ave.': 10.0,
#                           'Park Avenue': 6.0,
#                           'Park Hyatt Beaver Creek': 1.0,
#                           'Peng Shuai': 1.0,
#                           'Pengurusan Air': 1.0,
#                           'Peninsula Blvd': 2.0,
#                           'Penn': 2.0,
#                           'Penn State': 1.0,
#                           'Pennsylvania': 1.0,
#                           'Pennsylvania Avenue Northwest': 3.0,
#                           'Pentagon': 14.0,
#                           'Pentagon Memorial': 46.0,
#                           'Pine Street': 3.0,
#                           'Place Where Dreams': 34.0,
#                           'Plain Writing Act': 2.0,
#                           'Posh Rikers Island': 1.0,
#                           'Premium': 1.0,
#                           'Quantitative Easing': 1.0,
#                           'Red Square': 1.0,
#                           'Richardson GMP Limited': 4.0,
#                           'Riga Airport': 1.0,
#                           'Riker': 9.0,
#                           'Riker Island': 1.0,
#                           'Ritz Hotel': 1.0,
#                           'Robertsville Road Riverton': 3.0,
#                           'Rockingham Regional Memorial Park': 1.0,
#                           'Rome': 1.0,
#                           'S Oyster Bay Rd': 5.0,
#                           'Samsonite Laptop Bag': 1.0,
#                           'San City High': 1.0,
#                           'San Diego San Diego': 1.0,
#                           'San Diego State University': 3.0,
#                           'San Francisco': 1.0,
#                           'San Francisco Giants': 8.0,
#                           'San Jose Florida Marlins': 2.0,
#                           'San Vicente': 1.0,
#                           'Satellite Sentinel Project': 1.0,
#                           'Schottenfeld': 2.0,
#                           'Sea Hotel': 1.0,
#                           'Seton Hall': 1.0,
#                           'Seton Hall Expect': 1.0,
#                           'Seton Hall University': 1.0,
#                           'Siemens Middle East': 1.0,
#                           'Site': 3.0,
#                           'Site Credits': 2.0,
#                           'Site Index': 181.0,
#                           'Site Map': 50.0,
#                           'Site Map Copyright': 7.0,
#                           'Site Map Stay': 3.0,
#                           'Site Maps': 18.0,
#                           'Site Navigation': 1.0,
#                           'Site Tools': 6.0,
#                           'Sofia Hotel': 1.0,
#                           'Sofitel': 19.0,
#                           'Sofitel Hotel': 446.0,
#                           'Sofitel Hotel Penthouse': 1.0,
#                           'St Kliment Ohridski University': 2.0,
#                           'Stadium Beating': 3.0,
#                           'Stag Theatre': 1.0,
#                           'Stake': 1.0,
#                           'Stamford': 1.0,
#                           'Standby Credit Facility': 1.0,
#                           'Stanley': 2.0,
#                           'Stanley Cup': 3.0,
#                           'Stanley Cup Playoffs': 1.0,
#                           'Stanley Foundation': 14.0,
#                           'Starbucks': 1.0,
#                           'Stars': 3.0,
#                           'Stars More Flooding Expected': 1.0,
#                           'Stars View Recaps': 1.0,
#                           'State Street': 1.0,
#                           'State Street Global Markets': 3.0,
#                           'State Street Landing': 1.0,
#                           'Steeled Rikers Island Dominique': 1.0,
#                           'Stone Street Studios': 1.0,
#                           'Stop Loss Order': 2.0,
#                           'Suvarnabhumi': 13.0,
#                           'Taran Killam': 1.0,
#                           'Tech Mulch Ado': 2.0,
#                           'Tech Perry': 1.0,
#                           'Texas House': 3.0,
#                           'The': 9.0,
#                           'The American': 2.0,
#                           'The Atlantic': 2.0,
#                           'The Bay Citizen': 1.0,
#                           'The Boston Globe': 1.0,
#                           'The Bristol': 2.0,
#                           'The Bristol Plaza': 1.0,
#                           'The Brooklyn Paper': 1.0,
#                           'The Conseil Superieur': 1.0,
#                           'The Daily Beast': 9.0,
#                           'The Daily Caller': 1.0,
#                           'The Daily Meal Get': 1.0,
#                           'The Dallas': 1.0,
#                           'The Economist': 2.0,
#                           'The Economist Related': 1.0,
#                           'The Financial': 2.0,
#                           'The Globe': 2.0,
#                           'The Guardian': 1.0,
#                           'The Hague': 1.0,
#                           'The Herbert Suite': 1.0,
#                           'The Horsley Drive': 1.0,
#                           'The Independent': 1.0,
#                           'The Independent Sean': 1.0,
#                           'The Miami Herald': 1.0,
#                           'The Midnight Bell': 1.0,
#                           'The Museum': 1.0,
#                           'The New York Times': 9.0,
#                           'The New Yorker': 1.0,
#                           'The Office': 1.0,
#                           'The Peterson Institute': 1.0,
#                           'The Ranch Treatment Center': 1.0,
#                           'The Register-Guard': 5.0,
#                           'The Scheme': 1.0,
#                           'The Spectator': 1.0,
#                           'The Standard Sessions': 1.0,
#                           'The Studio': 1.0,
#                           'The Telegraph': 2.0,
#                           'The Times': 1.0,
#                           'The Tygrrrr Express': 1.0,
#                           'The Waldorf-Astoria': 1.0,
#                           'The Washington': 1.0,
#                           'The Washington Examiner': 1.0,
#                           'The Washington Post': 2.0,
#                           'The Weekly Standard': 1.0,
#                           'The World': 72.0,
#                           'Think Progress': 1.0,
#                           'Tiffany': 4.0,
#                           'Time Square': 3.0,
#                           'Times Square': 19.0,
#                           'Times Square Olive Garden': 1.0,
#                           'Times Square Sofitel': 11.0,
#                           'Times Square Sofitel Hotel': 12.0,
#                           'Tokyo Electric Power': 1.0,
#                           'Town Hall': 1.0,
#                           'Town Square': 1.0,
#                           'Trump': 2.0,
#                           'Trump Palace': 1.0,
#                           'Trump Tower': 1.0,
#                           'Truxtun Avenue': 2.0,
#                           'Unite': 1.0,
#                           'Val Caron': 2.0,
#                           'W': 5.0,
#                           'W Seoul': 2.0,
#                           'WHITE HOUSE': 2.0,
#                           'Walgreens': 2.0,
#                           'Wall St': 11.0,
#                           'Wall St.': 29.0,
#                           'Wall Street': 628.0,
#                           'Wall Street Breakfast': 3.0,
#                           'Wall Street Email': 1.0,
#                           'Wall Street Goes Crazy': 1.0,
#                           'Wall Street Hedge Farm': 1.0,
#                           'Wall Street Investment Banksters': 1.0,
#                           'Wall Street Journal': 215.0,
#                           'Wall Street Journal Europe': 1.0,
#                           'Wall Street Journal Set': 1.0,
#                           'Wall Street Journal Share': 1.0,
#                           'Wall Street Journal Tools': 6.0,
#                           'Wall Street Journal US Treasury': 1.0,
#                           'Wall Street Market Stats': 3.0,
#                           'Wall Street Pay': 6.0,
#                           'Wall Street Pit': 1.0,
#                           'Wall Street Swindled LinkedIn': 1.0,
#                           'Wall Street Takeover': 2.0,
#                           'Wall Street Warren Buffett': 2.0,
#                           'Wall Street Watcher': 1.0,
#                           'Water Street': 4.0,
#                           'Website': 12.0,
#                           'Website Reports': 1.0,
#                           'Weill Cornell Medical College': 1.0,
#                           'West': 1.0,
#                           'Westmoreland Times': 1.0,
#                           'Whiner': 1.0,
#                           'Whiner Line': 2.0,
#                           'Whiner Line No': 1.0,
#                           'White': 42.0,
#                           'White Army': 2.0,
#                           'White City': 1.0,
#                           'White Collar': 1.0,
#                           'White Defendant': 1.0,
#                           'White Elephant': 1.0,
#                           'White Elephant Sale': 2.0,
#                           'White Elephant Table': 2.0,
#                           'White Gave Up': 1.0,
#                           'White Hotel': 1.0,
#                           'White House': 682.0,
#                           'White House Bid': 2.0,
#                           'White House Carla': 1.0,
#                           'Sange': 18.0,
#                           'Children': 52.0,
#                           'Africa': 302.0,
#                           'Brazil': 660.0,
#                           'Tripoli': 85.0,
#                           'Yemen': 108.0,
#                           'North': 223.0,
#                           'Algiers': 18.0,
#                           'Algeria': 28.0,
#                           'London Africa': 18.0,
#                           'Libyan': 214.0,
#                           'United': 123.0,
#                           'Japanese': 558.0,
#                           'Buzz': 65.0,
#                           'Saudi': 109.0,
#                           'Customized': 20.0,
#                           'Know': 26.0,
#                           'Eight': 324.0,
#                           'Poland': 640.0,
#                           'Washington DC': 15.0,
#                           'Hungarian': 114.0,
#                           'Davos': 44.0,
#                           'Turbine': 1.0,
#                           'Loss': 9.0,
#                           'Index': 114.0,
#                           'Inc.': 40.0,
#                           'Ohio': 21.0,
#                           'New Jersey': 76.0,
#                           'Seaside': 1.0,
#                           'Sorta': 2.0,
#                           'New York State': 12.0,
#                           'Rikers': 195.0,
#                           'Rape': 23.0,
#                           'Print': 468.0,
#                           'Paper': 70.0,
#                           'Home': 244.0,
#                           'Long Island': 80.0,
#                           'Islip': 71.0,
#                           'Overcast': 34.0,
#                           'Radar': 76.0,
#                           'Hi': 72.0,
#                           'Settings': 71.0,
#                           'Long': 106.0,
#                           'Sports': 195.0,
#                           'Entertainment': 147.0,
#                           'Lifestyle': 103.0,
#                           'Health': 225.0,
#                           'Opinion': 125.0,
#                           'Cars': 91.0,
#                           'Add': 88.0,
#                           'Photos': 125.0,
#                           'Callahan': 1.0,
#                           'Matt': 6.0,
#                           'Boston': 78.0,
#                           'Julian': 5.0,
#                           'Bruins': 11.0,
#                           'Roberta': 1.0,
#                           'Roger': 1.0,
#                           'Demand': 44.0,
#                           'Celtic': 2.0,
#                           'Lackey': 7.0,
#                           'Mikey': 1.0,
#                           'Merloni': 1.0,
#                           'Columns': 9.0,
#                           'Blogs': 88.0,
#                           'Teams': 1.0,
#                           'Pakistan': 1087.0,
#                           'Berlin': 434.0,
#                           'Scotia': 3.0,
#                           'Race': 5.0,
#                           'Q3': 8.0,
#                           'Hong Kong': 270.0,
#                           'Economy': 55.0,
#                           'Norway': 71.0,
#                           'Personal': 4.0,
#                           'Libya': 595.0,
#                           'Sarko': 4.0,
#                           'Toronto': 131.0,
#                           'G8': 26.0,
#                           'R5.9bn': 1.0,
#                           'Eliot Spitzer': 1.0,
#                           'Warsaw': 91.0,
#                           'Mexico City': 71.0,
#                           'Georgia': 201.0,
#                           'Battle': 4.0,
#                           'Greenwich': 16.0,
#                           'Austria': 34.0,
#                           'Quanicia': 2.0,
#                           'D.C.': 128.0,
#                           'Author': 12.0,
#                           'Permalink': 117.0,
#                           'Glittarazzi': 9.0,
#                           'Fixnetix': 8.0,
#                           'Jaso': 8.0,
#                           'Asia Pacific': 11.0,
#                           'Brunswick': 4.0,
#                           'Latest': 90.0,
#                           'Russian': 392.0,
#                           'Lower': 72.0,
#                           'Sport': 44.0,
#                           'rendez-vous': 14.0,
#                           'sci-tech': 14.0,
#                           'hi-tech': 14.0,
#                           'Motion': 20.0,
#                           'Detroit': 16.0,
#                           'Chrysler': 4.0,
#                           'Virginia': 26.0,
#                           'Las': 7.0,
#                           'GPSWASHINGTON': 2.0,
#                           'Reston': 4.0,
#                           'Nevada': 19.0,
#                           'Retail': 18.0,
#                           'Healthcare': 5.0,
#                           'Thane': 2.0,
#                           'Cong': 6.0,
#                           'Varanasi': 4.0,
#                           'Mumbra': 1.0,
#                           'Nepal': 9.0,
#                           'Soviet': 65.0,
#                           'Qaeda': 4.0,
#                           'Kerala': 9.0,
#                           'Rs350': 1.0,
#                           'Pool': 170.0,
#                           'Elaine': 2.0,
#                           'Cannes': 450.0,
#                           'Cecilia': 53.0,
#                           'Pal': 26.0,
#                           'Stumble Upon': 20.0,
#                           'Linkedin': 17.0,
#                           'Los Angeles Times': 53.0,
#                           'Chirac': 24.0,
#                           'Fantasy Land': 1.0,
#                           'OP-ED': 3.0,
#                           'Leisure': 8.0,
#                           'Legal': 23.0,
#                           'Mission': 3.0,
#                           'Submissions': 3.0,
#                           'Masthead': 6.0,
#                           'Friend': 66.0,
#                           'Choice': 6.0,
#                           'Kimtag': 3.0,
#                           'Expand': 62.0,
#                           'El': 6.0,
#                           'Attempted': 2.0,
#                           'Colo': 1.0,
#                           'Colorado': 59.0,
#                           'Rock': 2.0,
#                           'Seattle': 31.0,
#                           'Bayer': 1.0,
#                           'Kazakh': 23.0,
#                           'MOSCOW': 4.0,
#                           'South Koreans': 17.0,
#                           'Munich': 114.0,
#                           'Lausanne': 79.0,
#                           'Morocco': 58.0,
#                           'South Korea': 291.0,
#                           'Alpensia': 16.0,
#                           'Seoul': 38.0,
#                           'Germans': 101.0,
#                           'Hotel': 32.0,
#                           'Gaithersburg': 37.0,
#                           'Irvine': 49.0,
#                           'Lebanon': 78.0,
#                           'Bail': 39.0,
#                           'New York Bail': 7.0,
#                           'Bulgaria': 48.0,
#                           'Search': 102.0,
#                           'World': 59.0,
#                           'New Flotilla': 1.0,
#                           'VIDEO': 7.0,
#                           'Invest': 17.0,
#                           'Alike': 7.0,
#                           'Bulgarian': 30.0,
#                           'Downtown': 3.0,
#                           'Survey': 4.0,
#                           'Downs': 8.0,
#                           'Wisdom': 9.0,
#                           'Football': 7.0,
#                           'Brief': 14.0,
#                           'YORK': 314.0,
#                           'Camille': 181.0,
#                           'Dallas': 31.0,
#                           'Jackson': 13.0,
#                           'New York Jets': 14.0,
#                           'Little Italy': 12.0,
#                           'Bangkok': 84.0,
#                           'New York County': 27.0,
#                           'Swiss': 393.0,
#                           'New York University': 9.0,
#                           'Liberty': 3.0,
#                           'Parisiennes': 1.0,
#                           'Translation': 39.0,
#                           'Go': 2.0,
#                           'French Studies': 5.0,
#                           'Mexican Peso': 1.0,
#                           'Spending': 3.0,
#                           'New America Media': 7.0,
#                           'Le Monde': 7.0,
#                           'Mediterranean': 5.0,
#                           'Simone': 1.0,
#                           'Sterling': 3.0,
#                           'British Land': 7.0,
#                           'Britvic': 1.0,
#                           'Burberry': 1.0,
#                           'Nationwide': 1.0,
#                           'England MPC': 1.0,
#                           'Middle Kingdom': 6.0,
#                           "O'bama": 18.0,
#                           'Osama': 206.0,
#                           'Dunand': 38.0,
#                           'Sarcelles': 44.0,
#                           'CHICAGO': 20.0,
#                           'Mo': 43.0,
# ...
#                           'Money Game Select': 20.0,
#                           'Page Select': 20.0,
#                           'Politix Select': 20.0,
#                           'Lifestyle Select': 20.0,
#                           'Tools Select': 20.0,
#                           'Apple Investor': 20.0,
#                           'Google Investor': 20.0,
#                           'French': 62.0,
#                           'Leszek Balcerowicz': 104.0,
#                           'Jean-Claude Trichet': 34.0,
#                           'Folha': 9.0,
#                           'Sao Paulo': 14.0,
#                           'German Finance': 45.0,
#                           'Wolfgang Schaeuble': 99.0,
#                           'Schaeuble': 46.0,
#                           'Chancellor Angela Merkel': 113.0,
#                           'Reduce': 62.0,
#                           'Increase': 62.0,
#                           'Tepco': 24.0,
#                           'Slide Shows': 44.0,
#                           'Wife': 7.0,
#                           'Mail': 14.0,
#                           'Stefan Collignon': 22.0,
#                           'Margaux': 20.0,
#                           'John McConnell': 284.0,
#                           'Such': 7.0,
#                           'Worlds Most': 1.0,
#                           'Worlds Largest Wind Farm': 1.0,
#                           'First GE Turbines Arrive': 1.0,
#                           'Zacks Investment Research': 4.0,
#                           'Hoover': 10.0,
#                           'Nomura Research Institute Ltd': 4.0,
#                           'Market Recap': 10.0,
#                           'Schaeffer': 5.0,
#                           'Market Commentary Via Acquire Media': 1.0,
#                           'Home Depot': 23.0,
#                           'Diamond Offshore': 2.0,
#                           'Anadarko Petroleum': 4.0,
#                           'Deutsche Boerse AG': 4.0,
#                           'Advance Auto Parts': 4.0,
#                           'Ohio': 9.0,
#                           'Krebs': 2.0,
#                           'Bernie Schaeffer': 4.0,
#                           'Soros Fund': 2.0,
#                           'Dow Jones Industrial Average': 10.0,
#                           'Nasdaq Composite': 3.0,
#                           'First Mia': 1.0,
#                           'Mia': 3.0,
#                           'Insert': 1.0,
#                           'Jersey Shore': 3.0,
#                           'Monsieur': 7.0,
#                           'Marine': 44.0,
#                           'Nina Pajak': 2.0,
#                           'Oda Mae Brown': 2.0,
#                           'Say': 7.0,
#                           'Make Good Villains': 2.0,
#                           'Mango Thief': 2.0,
#                           'Manhattan District Attorney': 41.0,
#                           'Erin Duggan': 70.0,
#                           'Source': 177.0,
#                           'Emmanuel': 13.0,
#                           'Images New York': 1.0,
#                           'Hotel': 49.0,
#                           'Port Authority': 62.0,
#                           'John F Kennedy': 48.0,
#                           'Le Point': 48.0,
#                           'Disqus': 121.0,
#                           'America': 32.0,
#                           'Fox Nation': 9.0,
#                           'Shakour Shaalan': 38.0,
#                           'Obus': 346.0,
#                           'Benefits': 501.0,
#                           'Paper': 168.0,
#                           'Order Optimum': 211.0,
#                           'Roadway': 36.0,
#                           'Other Traffic': 66.0,
#                           'Road': 74.0,
#                           'Willis': 14.0,
#                           'Little Neck Pkwy': 4.0,
#                           'Barometer': 71.0,
#                           'Register Log': 71.0,
#                           'Insider': 71.0,
#                           'Log': 75.0,
#                           'F8S BOYZ': 4.0,
#                           'Yellow Pages Long Island': 61.0,
#                           'Tech Health Business': 61.0,
#                           'Optimum': 71.0,
#                           'Originally': 4.0,
#                           'Quick ReadAP': 3.0,
#                           'Rick Gentilo': 58.0,
#                           'Tyler': 4.0,
#                           'Begin': 1.0,
#                           'Tampa Bay': 8.0,
#                           'Sega': 1.0,
#                           'Sean': 21.0,
#                           'Bergeron': 4.0,
#                           'Sagan': 1.0,
#                           'Clinton': 312.0,
#                           'Shutter': 1.0,
#                           'Montreal': 4.0,
#                           'Tampa': 8.0,
#                           'Summit': 2.0,
#                           'Michael': 34.0,
#                           'Tyler Sega': 1.0,
#                           'Roloson': 1.0,
#                           'Eric': 19.0,
#                           'Bobby Miller': 1.0,
#                           'Area': 3.0,
#                           'Played': 2.0,
#                           'Lucic': 1.0,
#                           'Allen': 11.0,
#                           'Broken': 4.0,
#                           'Bob Hope': 1.0,
#                           'Dominic': 25.0,
#                           'Metre': 1.0,
#                           'Patel': 1.0,
#                           'Jury': 4.0,
#                           'Audio': 6.0,
#                           'Draft Pick Nate': 1.0,
#                           'Jonathan Kraft': 3.0,
#                           'Patriots Draft Jonathan Kraft': 1.0,
#                           'Jonathan': 7.0,
#                           'Jon Barry': 3.0,
#                           'Glenn': 4.0,
#                           'Danny Ainge': 6.0,
#                           'Glenn Ordway': 2.0,
#                           'Michael Holley': 2.0,
#                           'Danny': 2.0,
#                           'Paul Pierce': 1.0,
#                           'Jackie MacMullan': 1.0,
#                           'Shaq': 2.0,
#                           'Adrian Gonzalez Postgame': 3.0,
#                           'Terry Francona Postgame': 2.0,
#                           'Lowrie Postgame': 2.0,
#                           'Mike Milbury': 3.0,
#                           'Mike': 32.0,
#                           'Finals': 2.0,
#                           'Patrice Bergeron': 5.0,
#                           'Tyler Seguin': 5.0,
#                           'Milan Lucic': 5.0,
#                           'Aaron Ward': 1.0,
#                           'Aaron': 3.0,
#                           'Guy Boucher': 1.0,
#                           'Claude Julien': 4.0,
#                           'Sports': 3.0,
#                           'Andy Brickley': 3.0,
#                           'Chris Herren': 7.0,
#                           'Boston Celtic Chris Herren': 2.0,
#                           'Fall River': 2.0,
#                           'John Lackey': 4.0,
#                           'Lou': 1.0,
#                           'Kevin Paul Dupont': 2.0,
#                           'Tampa Globe': 1.0,
#                           'Hockey Hall': 1.0,
#                           'Bruins': 9.0,
#                           'Kevin Youkilis': 3.0,
#                           'Miami Heat': 3.0,
#                           'Miamis': 1.0,
#                           'Mikey': 2.0,
#                           'Kirk Minihane': 3.0,
#                           'Kirk': 20.0,
#                           'Mon': 32.0,
#                           'Thhhhhhhhhhhheeeeee Yankeeeees': 1.0,
#                           'Doc Rivers': 2.0,
#                           'Jeff Green': 2.0,
#                           'Shaq Celtics Head': 1.0,
#                           'Big Baby': 1.0,
#                           'Jorge Posada': 4.0,
#                           'Mut': 1.0,
#                           'Adrian Gonzalez': 5.0,
#                           'Baltimore': 1.0,
#                           'Dino': 1.0,
#                           'Gerry': 11.0,
#                           'Weei Writers': 1.0,
#                           'Beckett': 4.0,
#                           'Red Sox': 7.0,
#                           'Patriots': 17.0,
#                           'Drew Bledsoe': 1.0,
#                           'Bill Russell': 7.0,
#                           'Christopher': 4.0,
#                           'Rob Gronkowski': 2.0,
#                           'Alex Speier': 2.0,
#                           'Daisuke Matsuzaka': 3.0,
#                           'Paul Flannery': 2.0,
#                           'Rob Bradford': 2.0,
#                           'Baby Mama': 8.0,
#                           'Sloppy': 1.0,
#                           'Full Count': 2.0,
#                           'Michael Bowden': 2.0,
#                           'Felix Doubront': 1.0,
#                           'Matt Friedman': 43.0,
#                           'Raphael G. Satter': 55.0,
#                           'Osama': 538.0,
#                           'Laden': 1416.0,
#                           'Olivier Picard': 2.0,
#                           'Les Dernières Nouvelles': 2.0,
#                           'Kennedy': 87.0,
#                           'Mark Carney': 121.0,
#                           'Bookie': 1.0,
#                           'Michael Babad': 1.0,
#                           'Follow Michael Babad': 1.0,
#                           'Twitter Bookie': 1.0,
#                           'Mr. Carney': 20.0,
#                           'William Hill': 62.0,
#                           'Augstin Carstens': 4.0,
#                           'Kevin Carmichael': 5.0,
#                           'Mr. Strauss-Kahn': 485.0,
#                           'Derek Holt': 6.0,
#                           'Karen Woods': 3.0,
#                           'Draghi': 57.0,
#                           'Trichet': 123.0,
#                           'Q1 GDP': 4.0,
#                           'Scotia Capital': 8.0,
#                           'Karen Cordes Woods': 3.0,
#                           'Statistics Canada': 5.0,
#                           'Avery Shenfeld': 4.0,
#                           'Glencore': 131.0,
#                           'Glencore International': 16.0,
#                           'Ivan Glasenberg': 5.0,
#                           'Globe': 8.0,
#                           'Mail European': 4.0,
#                           'Eric Reguly': 4.0,
#                           'Glencore IPO': 6.0,
#                           'Nikkei': 27.0,
#                           'Hang Seng': 107.0,
#                           'Robert Kavcic': 22.0,
#                           'Canada': 87.0,
#                           'Peter Kent': 3.0,
#                           'Andrew Leach': 2.0,
#                           'Brian Milner': 1.0,
#                           'Jan Willem': 1.0,
#                           'Rob Carrick': 7.0,
#                           'Tim Cestnick': 1.0,
#                           'Home Cents': 1.0,
#                           'Sonali Verma': 1.0,
#                           'Target': 16.0,
#                           'Google': 107.0,
#                           'Stephen Harper': 84.0,
#                           'Mr. Harper': 18.0,
#                           'Queen': 92.0,
#                           'Robert Wolfe': 1.0,
#                           'John Kirton': 8.0,
#                           'Mr. Sarkozy': 85.0,
#                           'Brett Solomon': 1.0,
#                           'Ottawa': 1.0,
#                           'Arab Spring': 49.0,
#                           'Kirton': 7.0,
#                           'Zeder Pioneer': 1.0,
#                           'Pioneer': 3.0,
#                           'Top Stories SA': 5.0,
#                           'Home Affairs': 9.0,
#                           'Johannesburg': 53.0,
#                           'Pioneer Food Group': 1.0,
#                           'Andre Hanekom': 1.0,
#                           'Pioneer Food Managing Director': 1.0,
#                           'Headline EPS': 2.0,
#                           'Arena': 4.0,
#                           'Spitzer': 117.0,
#                           'Rick Welts': 6.0,
#                           'Eric Schneiderman': 13.0,
#                           'Spitzer Hour': 1.0,
#                           'Kathleen Parker Splits': 1.0,
#                           'Wrap Stories': 1.0,
#                           'Remy De La Mauviniere': 39.0,
#                           'Zhu Min': 98.0,
#                           'Kin Cheung': 28.0,
#                           'Czarek Sokolowski': 38.0,
#                           'Marco Ugarte': 30.0,
#                           'Arminio Fraga Neto': 37.0,
#                           'Gavea Investments': 39.0,
#                           'Mark Lennihan': 34.0,
#                           'Share Larger': 109.0,
#                           'Smaller Printable Version Email': 156.0,
#                           'Verdana Times New Roman Arial Font': 127.0,
#                           'View RSS Feed': 186.0,
#                           'Resign Amid Sexual Assault Charges': 4.0,
#                           'Mike Segar': 7.0,
#                           'CLICK FOR': 16.0,
#                           'Erste Group Bank': 7.0,
#                           'Andreas Treichl': 7.0,
#                           'Basel III': 25.0,
#                           'Treichl': 5.0,
#                           'Erste': 10.0,
#                           'Michael Shields': 6.0,
#                           'Olli Rehn': 101.0,
#                           'Quentin Peel': 3.0,
#                           'Latest Videos Violent Lips': 2.0,
#                           'Caroline': 17.0,
#                           'Team Glittarazzi': 2.0,
#                           'Pink Cheetah': 2.0,
#                           'Glittarazzi Staff Rant No': 2.0,
#                           'David Arquette': 2.0,
#                           'Jason Biggs': 2.0,
#                           'Glittarazzi YouTube Channel': 2.0,
#                           'Main': 4.0,
#                           'Sofitel Hotel Housekeeper': 2.0,
#                           'Nicole': 2.0,
#                           'Share Article': 4.0,
#                           'Email Article': 10.0,
#                           'Article': 45.0,
#                           'View Printer Friendly Version': 3.0,
#                           'Friend Reader Comments': 2.0,
#                           'Author': 19.0,
#                           'Author Email': 2.0,
#                           'Author URL': 2.0,
#                           'Textile': 2.0,
#                           'Article Excerpt': 2.0,
#                           'Site URL': 2.0,
#                           'Glittarazzi': 8.0,
#                           'Rehn': 37.0,
#                           'Riva Froymovich': 1.0,
#                           'William Horobin': 4.0,
#                           'Aggregator Thomson Reuters': 4.0,
#                           'Sales Eric Barret': 8.0,
#                           'Trader Updates Consultancy': 3.0,
#                           'Nomura': 12.0,
#                           'Alpari': 3.0,
#                           'De': 3.0,
#                           'Panopticon': 1.0,
#                           'Panopticon Software': 1.0,
#                           'Caroline Nico': 4.0,
#                           'Frenchman Dominique': 347.0,
#                           'Pia Ahrenkilde Hansen': 32.0,
#                           'Thierry Mariani': 120.0,
#                           'Mr. Mariani': 2.0,
#                           'Bernard Valero': 13.0,
#                           'Jiang Yu': 142.0,
#                           'Klapper': 13.0,
#                           'Geir Moulson': 172.0,
#                           'Berlin': 162.0,
#                           'Angela Charlton': 111.0,
#                           'York Times': 2.0,
#                           'Men': 38.0,
#                           'Guard': 29.0,
#                           'Bill Murray': 5.0,
#                           'Britain': 18.0,
#                           'Online': 78.0,
#                           'Check': 61.0,
#                           ...})})
